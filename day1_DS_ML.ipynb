# %% [markdown]
# <a href="https://colab.research.google.com/github/muz1311/day1_DS_ML/blob/main/day1_DS_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###MATPLOTLIB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = sns.load_dataset('iris')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.plot(data['petal_length'])
plt.title("line charts using petal length")
plt.xlabel("indexes")
plt.ylabel("petal length")
plt.show()

# %%
plt.plot(data['sepal_width'])
plt.title("iris species",fontsize = 27)
plt.xlabel("indexes")
plt.ylabel("sepal_width")
plt.show()

# %%
plt.figure(figsize= (10,5))
plt.grid()

plt.plot(data['petal_length'],color = "black", label = "petal_length", linestyle = '--')
plt.plot(data['petal_width'],color = "green", label = "petal_width",linestyle = '--')
plt.plot(data['sepal_length'],color = "orange", label = "sepal_length",marker ='*')
plt.plot(data['sepal_width'],color = "blue", label = "sepal_width",marker ='+')
plt.title("line charts using petal length")
plt.xlabel("indexes")
plt.ylabel("multiple features")
plt.legend()
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.hist(tips['total_bill',bins=20,edgecolor='black'])
plt.show()
# Out:
#   File "<ipython-input-26-68e2aa227519>", line 1
#     plt.hist(tips['total_bill',bins=20,edgecolor='black'])
#                                    ^
# SyntaxError: invalid syntax
